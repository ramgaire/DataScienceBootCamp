# %%
#components of pandas.
#panda library
# introductio to series one dimensionof data, data frame is two dimension
# DAY ONE WITH EXRESCISE DATA SET IN TO DATA FRAME. CONVERGINT INTO DATE FORMAT.
# DATAR FRAME IS EASY TO WORK AND EASY TO PERFORM PERFORMANGCE.IMPORTING THE L

# %%
import numpy as np
import pandas as pd

# %%
#we keep numpy and pandas together.
#FUNCTIONOF SERIES IS SAME FOR DATA FRAME. 3 DAYS WITH US TO PERFORM EXERCISE.

# %%
#creatiung a data frame

# %%
# we keep numpy and pandas together.
# FUNCTIONOF SERIES IS SAME FOR DATA FRAME. 3 DAYS WITH US TO PERFORM EXERCISE.
# creatiung a data frame

# %%
list1 = [12,13,14,15,15,16,16,17,17,110,300]
df1 = pd.DataFrame(list1)
print(df1)
type(df1)
# Out:
#       0
# 0    12
# 1    13
# 2    14
# 3    15
# 4    15
# 5    16
# 6    16
# 7    17
# 8    17
# 9   110
# 10  300
# pandas.core.frame.DataFrame

# %% [markdown]
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# EMPTY DATA FRMAE FROMNUMPY

# %%
lang = ["c","c++","java","python"]
df2 = pd.DataFrame(lang)
print(df2)
# Out:
#         0
# 0       c
# 1     c++
# 2    java
# 3  python

# %%
rating= [3,4,5,6]
df2[1]= rating
df2
# Out:
#         0  1
# 0       c  3
# 1     c++  4
# 2    java  5
# 3  python  6

# %%
df2.columns = ('language','rating')
print(df2)
# Out:
#   language  rating
# 0        c       3
# 1      c++       4
# 2     java       5
# 3   python       6

# %%
tupel1 = (1,2,54,6,7,8,9)
df3 = pd.DataFrame(tupel1)

print(df3)
df3.columns = [('age','sex')]
print(df3)
# Out:
#     0
# 0   1
# 1   2
# 2  54
# 3   6
# 4   7
# 5   8
# 6   9
#    (age, sex)
# 0           1
# 1           2
# 2          54
# 3           6
# 4           7
# 5           8
# 6           9

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])

# %%
dict1 = pd.DataFrame({'id':[1,2,3,4],'name':['ramesh','suraj','ram','naresh']})
dict1
# Out:
#    id    name
# 0   1  ramesh
# 1   2   suraj
# 2   3     ram
# 3   4  naresh

# %% [markdown]
# i want to cath the values from diffrent
#
# 1.   List item
# 2.   List item

# %%
dict1['id'] ,dict1['name']
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  Name: id, dtype: int64,
#  0    ramesh
#  1     suraj
#  2       ram
#  3    naresh
#  Name: name, dtype: object)

# %%
dict2 = {'a':pd.Series([1,2,3,4],index = ['a','b','c','d'])
,'B':pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])}
df2 =pd.DataFrame(dict2)
df2
# Out:
#      a  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %% [markdown]
# # ****DateFrame****/
# date range function

# %%
dates = pd.date_range(start='01-august-2023',end = '31-aug-2023')
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range("today",periods =7)
dates
# Out:
# DatetimeIndex(['2023-09-06 00:11:46.770675', '2023-09-07 00:11:46.770675',
#                '2023-09-08 00:11:46.770675', '2023-09-09 00:11:46.770675',
#                '2023-09-10 00:11:46.770675', '2023-09-11 00:11:46.770675',
#                '2023-09-12 00:11:46.770675'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range("2023-08-25",periods =7)
dates
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
m = np.random.random((7,7))
m
# Out:
# array([[0.80840877, 0.57720061, 0.13780321, 0.67746442, 0.94649716,
#         0.61571271, 0.73697217],
#        [0.77871109, 0.66210932, 0.79350855, 0.80909248, 0.79124612,
#         0.59407851, 0.1421154 ],
#        [0.7057831 , 0.55527687, 0.28742785, 0.38550149, 0.87268069,
#         0.41200724, 0.38900727],
#        [0.02726381, 0.88967443, 0.96115254, 0.80428594, 0.12362663,
#         0.35551888, 0.18083084],
#        [0.84687748, 0.14925295, 0.99972377, 0.59603386, 0.57458909,
#         0.1569991 , 0.43869384],
#        [0.95685109, 0.1246482 , 0.84902086, 0.07254851, 0.9968725 ,
#         0.19393275, 0.27376869],
#        [0.79588469, 0.36773301, 0.85333752, 0.51764087, 0.09557741,
#         0.91585881, 0.3642646 ]])

# %%
df = pd.DataFrame(m,index = dates) # dates by defualt i sin descendingorder
df
# we  for the second value we need ot name it as index and assign it to it.
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                    6
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %% [markdown]
# in the structured way the data is organized

# %%
df.columns = ['c1','c2','c3','c4','c5','c6','c7']
df
#names the columns with the variables
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %% [markdown]
# ****changging the columns of data frame**** changing the header of teh data femae

# %%
df.sort_values(by='c1',ascending=True)
#It is arranging the c1 in the, so it is changing all rows along withit#
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
#
#                   c7
# 2023-08-28  0.180831
# 2023-08-27  0.389007
# 2023-08-26  0.142115
# 2023-08-31  0.364265
# 2023-08-25  0.736972
# 2023-08-29  0.438694
# 2023-08-30  0.273769

# %%
df.sort_values(by='c1',ascending= False)
#it give the descending order, first value is largest
# playing with ascending and making it true or false
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
#
#                   c7
# 2023-08-30  0.273769
# 2023-08-29  0.438694
# 2023-08-25  0.736972
# 2023-08-31  0.364265
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831

# %% [markdown]
# ****delete dataframe****

# %%
del df2['a'] # delete whole columns with the heading a
df2
# Out:
#    B
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
df['c1']
df
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.drop(['c1'],axis=1, inplace = True) # it means rows, axis = columns axis 0 menas row, axis =1 is column
df
# Out:
#                   c2        c3        c4        c5        c6        c7
# 2023-08-25  0.577201  0.137803  0.677464  0.946497  0.615713  0.736972
# 2023-08-26  0.662109  0.793509  0.809092  0.791246  0.594079  0.142115
# 2023-08-27  0.555277  0.287428  0.385501  0.872681  0.412007  0.389007
# 2023-08-28  0.889674  0.961153  0.804286  0.123627  0.355519  0.180831
# 2023-08-29  0.149253  0.999724  0.596034  0.574589  0.156999  0.438694
# 2023-08-30  0.124648  0.849021  0.072549  0.996872  0.193933  0.273769
# 2023-08-31  0.367733  0.853338  0.517641  0.095577  0.915859  0.364265

# %%
col1 = np.linspace(10, 100, 30) # gives number betwenn 10 and 100 and number of items will be 30
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  97
# 1    13.103448  22
# 2    16.206897  71
# 3    19.310345  62
# 4    22.413793  47
# 5    25.517241  54
# 6    28.620690  13
# 7    31.724138  48
# 8    34.827586  19
# 9    37.931034  28
# 10   41.034483  52
# 11   44.137931  99
# 12   47.241379  85
# 13   50.344828  41
# 14   53.448276  53
# 15   56.551724  51
# 16   59.655172  33
# 17   62.758621  92
# 18   65.862069  53
# 19   68.965517  66
# 20   72.068966  19
# 21   75.172414  24
# 22   78.275862  47
# 23   81.379310  53
# 24   84.482759  27
# 25   87.586207  29
# 26   90.689655  42
# 27   93.793103  13
# 28   96.896552  89
# 29  100.000000  63

# %%
import pandas as pd
df10 = df10.drop([17,18,19], axis =0)
df10
# Out:
#             C1  C2
# 0    10.000000  97
# 1    13.103448  22
# 2    16.206897  71
# 3    19.310345  62
# 4    22.413793  47
# 5    25.517241  54
# 6    28.620690  13
# 7    31.724138  48
# 8    34.827586  19
# 9    37.931034  28
# 10   41.034483  52
# 11   44.137931  99
# 12   47.241379  85
# 13   50.344828  41
# 14   53.448276  53
# 15   56.551724  51
# 16   59.655172  33
# 20   72.068966  19
# 21   75.172414  24
# 22   78.275862  47
# 23   81.379310  53
# 24   84.482759  27
# 25   87.586207  29
# 26   90.689655  42
# 27   93.793103  13
# 28   96.896552  89
# 29  100.000000  63

# %%
df10 = df10.drop([10], axis=0, inplace = True)
df10

# %%
#delete with the help of index
df10.drop(df10.index[5],inplace = True)
df10
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-34d2fd92398f> in <cell line: 2>()
#       1 #delete with the help of index
# ----> 2 df10.drop(df10.index[5],inplace = True)
#       3 df10
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df10.iloc[10:15]

# %%
df10.iloc[10:15, 0]

# %%
df10.iloc[10:,0:]

# %%
df10.iloc[10:15]

# %% [markdown]
# ****CODING SECCISSION****
# OOPS

# %%
df10.loc[:,'C4':]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-798a2a829daf> in <cell line: 1>()
# ----> 1 df10.loc[:,'C4':]
#
# AttributeError: 'NoneType' object has no attribute 'loc'

# %%
df = pd.DataFrame(m,index = dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                    6
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
col1 = np.linspace(10, 100, 30) # gives number betwenn 10 and 100 and number of items will be 30
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  82
# 1    13.103448  51
# 2    16.206897  68
# 3    19.310345  50
# 4    22.413793  10
# 5    25.517241  80
# 6    28.620690  74
# 7    31.724138  69
# 8    34.827586  86
# 9    37.931034  80
# 10   41.034483  96
# 11   44.137931  38
# 12   47.241379  69
# 13   50.344828  53
# 14   53.448276  23
# 15   56.551724  33
# 16   59.655172  53
# 17   62.758621  60
# 18   65.862069  67
# 19   68.965517  44
# 20   72.068966  61
# 21   75.172414  18
# 22   78.275862  73
# 23   81.379310  46
# 24   84.482759  51
# 25   87.586207  25
# 26   90.689655  92
# 27   93.793103  46
# 28   96.896552  77
# 29  100.000000  67

# %%
df.columns = ['c1','c2','c3','c4','c5','c6','c7']
df
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.loc[:,:]
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.loc['25-08-2023': '25-08-2023','c1': 'c1']
# Out:
# <ipython-input-73-a2c995d1d221>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023': '25-08-2023','c1': 'c1']
#                   c1
# 2023-08-25  0.808409

# %%
df.loc['26-08-2023': '26-08-2023','c2': 'c2']
# Out:
# <ipython-input-74-e2e8982b05f0>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023': '26-08-2023','c2': 'c2']
#                   c2
# 2023-08-26  0.662109

# %%
df.loc['27-08-2023': '27-08-2023','c3': 'c3']
# Out:
# <ipython-input-76-0ac30c62ad39>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023': '27-08-2023','c3': 'c3']
#                   c3
# 2023-08-27  0.287428

# %%
df.loc['28-08-2023': '28-08-2023','c4': 'c4']
# Out:
# <ipython-input-77-43f826f26546>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023': '28-08-2023','c4': 'c4']
#                   c4
# 2023-08-28  0.804286

# %%
df.loc['29-08-2023': '29-08-2023','c5': 'c5']
# Out:
# <ipython-input-78-a432b984c160>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023': '29-08-2023','c5': 'c5']
#                   c5
# 2023-08-29  0.574589

# %%
df.loc['30-08-2023': '30-08-2023','c6': 'c6']
# Out:
# <ipython-input-79-980e2c8b78a2>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023': '30-08-2023','c6': 'c6']
#                   c6
# 2023-08-30  0.193933

# %%
df.loc['31-08-2023': '31-08-2023','c7': 'c7']
# Out:
# <ipython-input-80-d5b7cd01b4b8>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023': '31-08-2023','c7': 'c7']
#                   c7
# 2023-08-31  0.364265

# %%
#Revwerserd diagonal
df.loc['31-08-2023': '31-08-2023','c1': 'c1']
# Out:
# <ipython-input-81-4748dbdcd5ee>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['31-08-2023': '31-08-2023','c1': 'c1']
#                   c1
# 2023-08-31  0.795885

# %%
df.loc['30-08-2023': '30-08-2023','c2': 'c2']
# Out:
# <ipython-input-82-feb8296a23f3>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['30-08-2023': '30-08-2023','c2': 'c2']
#                   c2
# 2023-08-30  0.124648

# %%
df.loc['29-08-2023': '29-08-2023','c3': 'c3']
# Out:
# <ipython-input-83-aa8224850c3f>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['29-08-2023': '29-08-2023','c3': 'c3']
#                   c3
# 2023-08-29  0.999724

# %%
df.loc['28-08-2023': '28-08-2023','c4': 'c4']
# Out:
# <ipython-input-84-43f826f26546>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['28-08-2023': '28-08-2023','c4': 'c4']
#                   c4
# 2023-08-28  0.804286

# %%
df.loc['27-08-2023': '27-08-2023','c5': 'c5']
# Out:
# <ipython-input-85-5bb27f4155c8>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['27-08-2023': '27-08-2023','c5': 'c5']
#                   c5
# 2023-08-27  0.872681

# %%
df.loc['26-08-2023': '26-08-2023','c6': 'c6']
# Out:
# <ipython-input-86-9d00894c7839>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['26-08-2023': '26-08-2023','c6': 'c6']
#                   c6
# 2023-08-26  0.594079

# %%
df.loc['25-08-2023': '25-08-2023','c7': 'c7']
# Out:
# <ipython-input-87-07bec39e8603>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.loc['25-08-2023': '25-08-2023','c7': 'c7']
#                   c7
# 2023-08-25  0.736972

# %%
df.iloc[:,:]
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.iloc[3:,:]
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.iloc[:4,:]
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831

# %%
df.iloc[:,3:]
# Out:
#                   c4        c5        c6        c7
# 2023-08-25  0.677464  0.946497  0.615713  0.736972
# 2023-08-26  0.809092  0.791246  0.594079  0.142115
# 2023-08-27  0.385501  0.872681  0.412007  0.389007
# 2023-08-28  0.804286  0.123627  0.355519  0.180831
# 2023-08-29  0.596034  0.574589  0.156999  0.438694
# 2023-08-30  0.072549  0.996872  0.193933  0.273769
# 2023-08-31  0.517641  0.095577  0.915859  0.364265

# %%
df.iloc[:,:4] #rows and columsn
# Out:
#                   c1        c2        c3        c4
# 2023-08-25  0.808409  0.577201  0.137803  0.677464
# 2023-08-26  0.778711  0.662109  0.793509  0.809092
# 2023-08-27  0.705783  0.555277  0.287428  0.385501
# 2023-08-28  0.027264  0.889674  0.961153  0.804286
# 2023-08-29  0.846877  0.149253  0.999724  0.596034
# 2023-08-30  0.956851  0.124648  0.849021  0.072549
# 2023-08-31  0.795885  0.367733  0.853338  0.517641

# %%
df
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.iloc[:,:2] # taking all rows and ending columns with second index of column

# %%
df.iloc[:,4:] # taking all rows and starting columns from n +1 rules

# %%
#reverse diagonal values using iloc ilock takes index, lock take values
df.iloc
# Out:
#                   c4
# 2023-08-28  0.804286

# %%
#loc says we need to take column name nad row names
df.loc['2023-08-27':,:'2023-08-30']

# %%
df.iloc[6:,:2]
# Out:
#                   c1        c2
# 2023-08-31  0.795885  0.367733

# %%
df
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.iloc[3:,:]
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.iloc[:3,:] #row index 0,1,2
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007

# %%
df.iloc[:,2:]
# Out:
#                   c3        c4        c5        c6        c7
# 2023-08-25  0.137803  0.677464  0.946497  0.615713  0.736972
# 2023-08-26  0.793509  0.809092  0.791246  0.594079  0.142115
# 2023-08-27  0.287428  0.385501  0.872681  0.412007  0.389007
# 2023-08-28  0.961153  0.804286  0.123627  0.355519  0.180831
# 2023-08-29  0.999724  0.596034  0.574589  0.156999  0.438694
# 2023-08-30  0.849021  0.072549  0.996872  0.193933  0.273769
# 2023-08-31  0.853338  0.517641  0.095577  0.915859  0.364265

# %%
df.iloc[:,:4]

# %%
#df.iloc[6:,:1]
df
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.808409  0.577201  0.137803  0.677464  0.946497  0.615713
# 2023-08-26  0.778711  0.662109  0.793509  0.809092  0.791246  0.594079
# 2023-08-27  0.705783  0.555277  0.287428  0.385501  0.872681  0.412007
# 2023-08-28  0.027264  0.889674  0.961153  0.804286  0.123627  0.355519
# 2023-08-29  0.846877  0.149253  0.999724  0.596034  0.574589  0.156999
# 2023-08-30  0.956851  0.124648  0.849021  0.072549  0.996872  0.193933
# 2023-08-31  0.795885  0.367733  0.853338  0.517641  0.095577  0.915859
#
#                   c7
# 2023-08-25  0.736972
# 2023-08-26  0.142115
# 2023-08-27  0.389007
# 2023-08-28  0.180831
# 2023-08-29  0.438694
# 2023-08-30  0.273769
# 2023-08-31  0.364265

# %%
df.iloc[6:,:1]
# Out:
#                   c1
# 2023-08-31  0.795885

# %%
df.iloc[5:6,1:2]
# Out:
#                   c2
# 2023-08-30  0.124648

# %%
df.iloc[4:5,2:3]
# Out:
#                   c3
# 2023-08-29  0.999724

# %%
df.iloc[3:4,3:4]
# Out:
#                   c4
# 2023-08-28  0.804286

# %%
df.iloc[2:3,5:6]  #menad index n-1 rules. stary at index 5
# Out:
#                   c6
# 2023-08-27  0.412007

# %%
df.iloc[0:1,6:7]
# Out:
#                   c7
# 2023-08-25  0.736972

# %%
path = '/content/Churn_Modelling.csv'
ram = pd.read_csv(path)
ram
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
ram.iloc[3:10,6:9] # third row tp 10ty row, 6th cloum to 9th column by indexing the
# Out:
#    Age  Tenure    Balance
# 3   39       1       0.00
# 4   43       2  125510.82
# 5   44       8  113755.78
# 6   50       7       0.00
# 7   29       4  115046.74
# 8   44       4  142051.07
# 9   27       2  134603.88

# %%
ram.iloc[1500:2300,6:9]
# Out:
#       Age  Tenure    Balance
# 1500   50       1   81947.76
# 1501   31       7  144162.30
# 1502   39       5   86350.87
# 1503   47       5  158623.14
# 1504   32       8       0.00
# ...   ...     ...        ...
# 2295   40       7       0.00
# 2296   47       9  110022.74
# 2297   40       9  131569.63
# 2298   61       2  164523.50
# 2299   25       2  114330.95
#
# [800 rows x 3 columns]

# %%
ram.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
ram.sort_values('Gender')
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602  Hargrave          619    France  Female   42
# 5366       5367    15812230    Elliot          670   Germany  Female   42
# 5362       5363    15779985        Lo          750   Germany  Female   37
# 5355       5356    15773751        Y?          597    France  Female   29
# 5352       5353    15675749   Baranov          695    France  Female   23
# ...         ...         ...       ...          ...       ...     ...  ...
# 6233       6234    15682914    Bolton          850    France    Male   34
# 3901       3902    15714610  Alexeeva          575     Spain    Male   30
# 6231       6232    15729238      Peng          631   Germany    Male   48
# 6239       6240    15682369    Pisano          613    France    Male   47
# 6553       6554    15607526        Lu          638   Germany    Male   50
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
ram.iloc[1500:2300,8:9]
# Out:
#         Balance
# 1500   81947.76
# 1501  144162.30
# 1502   86350.87
# 1503  158623.14
# 1504       0.00
# ...         ...
# 2295       0.00
# 2296  110022.74
# 2297  131569.63
# 2298  164523.50
# 2299  114330.95
#
# [800 rows x 1 columns]

# %%
ram.loc['2':'3','Surname':'Age']
# Out:
#          Surname  CreditScore Geography  Gender  Age
# 2000    Lombardi          842    France    Male   58
# 2001    Hamilton          661    France  Female   27
# 2002        Hsia          601    France    Male   74
# 2003         Mao          632    France    Male   41
# 2004   Ugochukwu          684   Germany    Male   29
# ...          ...          ...       ...     ...  ...
# 2995       Moore          535    France  Female   29
# 2996  Yobachukwu          729     Spain  Female   45
# 2997     Fleming          655    France  Female   26
# 2998   Dickinson          751    France    Male   47
# 2999     Evseyev          525    France    Male   33
#
# [1000 rows x 5 columns]

# %%
ram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
ram.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
ram.describe
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
ram.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
ram.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
ram.size
# Out:
# 140000

# %%
ram.ndim
# Out:
# 2

# %%
ram.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
ram.count
# Out:
# <bound method DataFrame.count of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
ram.shape
# Out:
# (10000, 14)

# %%
#Expolaratorary data analysis (EDA), VERY IMPORTANT PYTHON PANDAS,AND NUMPY LIBRARY,VISULATION.

# %%
ram.sum(axis=0) #gives sum of each column
# Out:
# RowNumber                                                   50005000
# CustomerId                                              156909405694
# Surname            HargraveHillOnioBoniMitchellChuBartlettObinnaH...
# CreditScore                                                  6505288
# Geography          FranceSpainFranceFranceSpainSpainFranceGermany...
# Gender             FemaleFemaleFemaleFemaleFemaleMaleMaleFemaleMa...
# Age                                                           389218
# Tenure                                                         50128
# Balance                                                 764858892.88
# NumOfProducts                                                  15302
# HasCrCard                                                       7055
# IsActiveMember                                                  5151
# EstimatedSalary                                        1000902398.81
# Exited                                                          2037
# ...

# %%
ram.count()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname            10000
# CreditScore        10000
# Geography          10000
# Gender             10000
# Age                10000
# Tenure             10000
# Balance            10000
# NumOfProducts      10000
# HasCrCard          10000
# IsActiveMember     10000
# EstimatedSalary    10000
# Exited             10000
# dtype: int64

# %%
ram.min()
# Out:
# RowNumber                 1
# CustomerId         15565701
# Surname               Abazu
# CreditScore             350
# Geography            France
# Gender               Female
# Age                      18
# Tenure                    0
# Balance                 0.0
# NumOfProducts             1
# HasCrCard                 0
# IsActiveMember            0
# EstimatedSalary       11.58
# Exited                    0
# dtype: object

# %%
ram.max()
# Out:
# RowNumber              10000
# CustomerId          15815690
# Surname               Zuyeva
# CreditScore              850
# Geography              Spain
# Gender                  Male
# Age                       92
# Tenure                    10
# Balance            250898.09
# NumOfProducts              4
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    199992.48
# Exited                     1
# dtype: object

# %%
ram.std()
# Out:
# <ipython-input-259-b6240d09a570>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ram.std()
# RowNumber           2886.895680
# CustomerId         71936.186123
# CreditScore           96.653299
# Age                   10.487806
# Tenure                 2.892174
# Balance            62397.405202
# NumOfProducts          0.581654
# HasCrCard              0.455840
# IsActiveMember         0.499797
# EstimatedSalary    57510.492818
# Exited                 0.402769
# dtype: float64

# %%
ram.sum(axis=1)
# Out:
# <ipython-input-261-dc23aaf6e267>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ram.sum(axis=1)
# 0       15736618.88
# 1       15844315.44
# 2       15893456.37
# 3       15795925.63
# 4       15943385.92
#            ...
# 9995    15713313.64
# 9996    15739522.38
# 9997    15637370.58
# 9998    15861138.83
# 9999    15807478.57
# Length: 10000, dtype: float64

# %%
ram.CreditScore
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
ram['CreditScore'] # it is useful when we have space
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
ram[['CreditScore','Balance']] # two dimension data
#ram.Balance,ram.CreditScore
# Out:
#       CreditScore    Balance
# 0             619       0.00
# 1             608   83807.86
# 2             502  159660.80
# 3             699       0.00
# 4             850  125510.82
# ...           ...        ...
# 9995          771       0.00
# 9996          516   57369.61
# 9997          709       0.00
# 9998          772   75075.31
# 9999          792  130142.79
#
# [10000 rows x 2 columns]

# %%
ram.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
ram[['Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard','Surname', 'EstimatedSalary']] # this method is very useful

# %% [markdown]
# ****Data selection based on condition****

# %%
ram[(ram.Gender=='Male') & (ram.Age <=20) &(ram.Balance>100000)]

# %%
ram[(ram.NumOfProducts>10)]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
ram[(ram.EstimatedSalary>100000) | (ram.Gender=='Female') | (ram.Balance>1000000)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 1             2    15647311         Hill          608     Spain  Female   41
# 2             3    15619304         Onio          502    France  Female   42
# 3             4    15701354         Boni          699    France  Female   39
# 4             5    15737888     Mitchell          850     Spain  Female   43
# ...         ...         ...          ...          ...       ...     ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9994       9995    15719294         Wood          800    France  Female   29
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
# 9999      10000    15628319       Walker          792    France  Female   28
#
# ...

# %%
ram.Surname.unique() # givs the uniques names in teh arry but need to put the
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Kashiwagi', 'Aldridge',
#        'Burbidge'], dtype=object)

# %%
a = [12,213,34,45,5,1,5,]
b = 12
b in a
# Out:
# True

# %%
# Out:
#   File "<ipython-input-350-9406adf43b31>", line 1
#     ram.[['France','Germany']' in ['Geography']]
#                                              ^
# SyntaxError: unterminated string literal (detected at line 1)
