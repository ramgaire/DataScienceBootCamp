# %%
#components of pandas.
#panda library
# introductio to series one dimensionof data, data frame is two dimension
# DAY ONE WITH EXRESCISE DATA SET IN TO DATA FRAME. CONVERGINT INTO DATE FORMAT.
# DATAR FRAME IS EASY TO WORK AND EASY TO PERFORM PERFORMANGCE.IMPORTING THE L

# %%
import numpy as np
import pandas as pd

# %%
#we keep numpy and pandas together.
#FUNCTIONOF SERIES IS SAME FOR DATA FRAME. 3 DAYS WITH US TO PERFORM EXERCISE.

# %%
#creatiung a data frame

# %%
# we keep numpy and pandas together.
# FUNCTIONOF SERIES IS SAME FOR DATA FRAME. 3 DAYS WITH US TO PERFORM EXERCISE.
# creatiung a data frame

# %%
list1 = [12,13,14,15,15,16,16,17,17,110,300]
df1 = pd.DataFrame(list1)
print(df1)
type(df1)
# Out:
#       0
# 0    12
# 1    13
# 2    14
# 3    15
# 4    15
# 5    16
# 6    16
# 7    17
# 8    17
# 9   110
# 10  300
# pandas.core.frame.DataFrame

# %% [markdown]
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# EMPTY DATA FRMAE FROMNUMPY

# %%
lang = ["c","c++","java","python"]
df2 = pd.DataFrame(lang)
print(df2)
# Out:
#         0
# 0       c
# 1     c++
# 2    java
# 3  python

# %%
rating= [3,4,5,6]
df2[1]= rating
df2
# Out:
#         0  1
# 0       c  3
# 1     c++  4
# 2    java  5
# 3  python  6

# %%
df2.columns = ('language','rating')
print(df2)
# Out:
#   language  rating
# 0        c       3
# 1      c++       4
# 2     java       5
# 3   python       6

# %%
tupel1 = (1,2,54,6,7,8,9)
df3 = pd.DataFrame(tupel1)

print(df3)
df3.columns = [('age','sex')]
print(df3)
# Out:
#     0
# 0   1
# 1   2
# 2  54
# 3   6
# 4   7
# 5   8
# 6   9
#    (age, sex)
# 0           1
# 1           2
# 2          54
# 3           6
# 4           7
# 5           8
# 6           9

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])

# %%
dict1 = pd.DataFrame({'id':[1,2,3,4],'name':['ramesh','suraj','ram','naresh']})
dict1
# Out:
#    id    name
# 0   1  ramesh
# 1   2   suraj
# 2   3     ram
# 3   4  naresh

# %% [markdown]
# i want to cath the values from diffrent
#
# 1.   List item
# 2.   List item

# %%
dict1['id'] ,dict1['name']
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  Name: id, dtype: int64,
#  0    ramesh
#  1     suraj
#  2       ram
#  3    naresh
#  Name: name, dtype: object)

# %%
dict2 = {'a':pd.Series([1,2,3,4],index = ['a','b','c','d'])
,'B':pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])}
df2 =pd.DataFrame(dict2)
df2
# Out:
#      a  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %% [markdown]
# # ****DateFrame****/
# date range function

# %%
dates = pd.date_range(start='01-august-2023',end = '31-aug-2023')
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range("today",periods =7)
dates
# Out:
# DatetimeIndex(['2023-09-02 02:02:52.774630', '2023-09-03 02:02:52.774630',
#                '2023-09-04 02:02:52.774630', '2023-09-05 02:02:52.774630',
#                '2023-09-06 02:02:52.774630', '2023-09-07 02:02:52.774630',
#                '2023-09-08 02:02:52.774630'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range("2023-08-25",periods =7)
dates
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
m = np.random.random((7,7))
m
# Out:
# array([[0.39428257, 0.82738474, 0.09028783, 0.20482887, 0.51891202,
#         0.66643663, 0.91297047],
#        [0.4833415 , 0.01637641, 0.38633933, 0.82142466, 0.91470207,
#         0.10201444, 0.00265552],
#        [0.15642254, 0.04402458, 0.75132498, 0.06876434, 0.86042752,
#         0.66613193, 0.79786362],
#        [0.34798942, 0.21941347, 0.16920227, 0.61951856, 0.15817883,
#         0.49179875, 0.53623295],
#        [0.10741638, 0.18406971, 0.50654046, 0.33337128, 0.88614357,
#         0.12429403, 0.3003557 ],
#        [0.78580523, 0.42641103, 0.08297365, 0.97749711, 0.12034012,
#         0.47248571, 0.96438782],
#        [0.92658831, 0.62053046, 0.23146997, 0.26415304, 0.13562994,
#         0.87931914, 0.11739171]])

# %%
df = pd.DataFrame(m,index = dates) # dates by defualt i sin descendingorder
df
# we  for the second value we need ot name it as index and assign it to it.
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.394283  0.827385  0.090288  0.204829  0.518912  0.666437
# 2023-08-26  0.483342  0.016376  0.386339  0.821425  0.914702  0.102014
# 2023-08-27  0.156423  0.044025  0.751325  0.068764  0.860428  0.666132
# 2023-08-28  0.347989  0.219413  0.169202  0.619519  0.158179  0.491799
# 2023-08-29  0.107416  0.184070  0.506540  0.333371  0.886144  0.124294
# 2023-08-30  0.785805  0.426411  0.082974  0.977497  0.120340  0.472486
# 2023-08-31  0.926588  0.620530  0.231470  0.264153  0.135630  0.879319
#
#                    6
# 2023-08-25  0.912970
# 2023-08-26  0.002656
# 2023-08-27  0.797864
# 2023-08-28  0.536233
# 2023-08-29  0.300356
# 2023-08-30  0.964388
# 2023-08-31  0.117392

# %% [markdown]
# in the structured way the data is organized

# %%
df.columns = ['c1','c2','c3','c4','c5','c6','c7']
df
#names the columns with the variables
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 2023-08-25  0.394283  0.827385  0.090288  0.204829  0.518912  0.666437
# 2023-08-26  0.483342  0.016376  0.386339  0.821425  0.914702  0.102014
# 2023-08-27  0.156423  0.044025  0.751325  0.068764  0.860428  0.666132
# 2023-08-28  0.347989  0.219413  0.169202  0.619519  0.158179  0.491799
# 2023-08-29  0.107416  0.184070  0.506540  0.333371  0.886144  0.124294
# 2023-08-30  0.785805  0.426411  0.082974  0.977497  0.120340  0.472486
# 2023-08-31  0.926588  0.620530  0.231470  0.264153  0.135630  0.879319
#
#                   c7
# 2023-08-25  0.912970
# 2023-08-26  0.002656
# 2023-08-27  0.797864
# 2023-08-28  0.536233
# 2023-08-29  0.300356
# 2023-08-30  0.964388
# 2023-08-31  0.117392

# %% [markdown]
# ****changging the columns of data frame**** changing the header of teh data femae

# %%
df.sort_values(by='c1',ascending=True)
#It is arranging the c1 in the, so it is changing all rows along withit#
# Out:
#                   c1        c2        c3        c4        c5        c6  \
# 
# 2023-08-30  0.426411  0.082974  0.977497  0.120340  0.472486  0.964388
# 2023-08-31  0.620530  0.231470  0.264153  0.135630  0.879319  0.117392

# %%
col1 = np.linspace(10, 100, 30) # gives number betwenn 10 and 100 and number of items will be 30
col2 = np.random.randint(10,100,30)
df10 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df10
# Out:
#             C1  C2
# 0    10.000000  15
# 1    13.103448  45
# 2    16.206897  47
# 3    19.310345  27
# 4    22.413793  86
# 5    25.517241  20
# 6    28.620690  54
# 7    31.724138  83
# 8    34.827586  56
# 9    37.931034  41
# 10   41.034483  92
# 11   44.137931  31
# 12   47.241379  73
# 13   50.344828  87
# 14   53.448276  19
# 15   56.551724  28
# 16   59.655172  99
# 17   62.758621  23
# 18   65.862069  16
# 19   68.965517  15
# 20   72.068966  80
# 21   75.172414  91
# 22   78.275862  49
# 23   81.379310  21
# 24   84.482759  44
# 25   87.586207  20
# 26   90.689655  33
# 27   93.793103  23
# 28   96.896552  86
# 29  100.000000  22

# %%
import pandas as pd
df10 = df10.drop([17,18,19], axis =0)
df10
# Out:
#             C1  C2
# 0    10.000000  15
# 1    13.103448  45
# 2    16.206897  47
# 3    19.310345  27
# 4    22.413793  86
# 5    25.517241  20
# 6    28.620690  54
# 7    31.724138  83
# 8    34.827586  56
# 9    37.931034  41
# 10   41.034483  92
# 11   44.137931  31
# 12   47.241379  73
# 13   50.344828  87
# 14   53.448276  19
# 15   56.551724  28
# 16   59.655172  99
# 20   72.068966  80
# 21   75.172414  91
# 22   78.275862  49
# 23   81.379310  21
# 24   84.482759  44
# 25   87.586207  20
# 26   90.689655  33
# 27   93.793103  23
# 28   96.896552  86
# 29  100.000000  22

# %%
df10 = df10.drop([10], axis=0, inplace = True)
df10
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-257-10191904f443> in <cell line: 1>()
# ----> 1 df10 = df10.drop([10], axis=0, inplace = True)
#       2 df10
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
#delete with the help of index
df10.drop(df10.index[5],inplace = True)
df10
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-259-34d2fd92398f> in <cell line: 2>()
#       1 #delete with the help of index
# ----> 2 df10.drop(df10.index[5],inplace = True)
#       3 df10
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 11  44.137931  31
# 12  47.241379  73
# 13  50.344828  87
# 14  53.448276  19
# 15  56.551724  28

# %%
df10.iloc[10:15, 0]
# Out:
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df10.iloc[10:,0:]
# Out:
#             C1  C2
# 11   44.137931  31
# 12   47.241379  73
# 13   50.344828  87
# 14   53.448276  19
# 15   56.551724  28
# 16   59.655172  99
# 20   72.068966  80
# 21   75.172414  91
# 22   78.275862  49
# 23   81.379310  21
# 24   84.482759  44
# 25   87.586207  20
# 26   90.689655  33
# 27   93.793103  23
# 28   96.896552  86
# 29  100.000000  22

# %%
df10.iloc[10:15]
# Out:
#            C1  C2
# 11  44.137931  31
# 12  47.241379  73
# 13  50.344828  87
# 14  53.448276  19
# 15  56.551724  28

# %% [markdown]
# ****CODING SECCISSION****
# OOPS
