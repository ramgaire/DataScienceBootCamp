# %% [markdown]
# #**Exploratory data analysis (EDA)**
#
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = '/content/zomato.csv'
df_zomato = pd.read_csv(path, encoding='latin-1')
df_zomato
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df_zomato.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
df_zomato.tail(10)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9541        5905215           Emirgan Sí_tiô           208  ÛÁstanbul
# 9542        5926979            Leman Kí_ltí_r           208  ÛÁstanbul
# 9543        5916085              Dem Karakí_y           208  ÛÁstanbul
# 9544        5915547     Karakí_y Gí_llí_oÛôlu           208  ÛÁstanbul
# 9545        5915054                  Baltazar           208  ÛÁstanbul
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address          Locality  \
# 9541  Emirgan Mahallesi, SakÛ±p SabancÛ± Caddesi, No...          Emirgí¢n
# ...

# %%
df_zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df_zomato.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# #**In Data Analysis What All Things We Do**
#
#     1. Missing Values
#     2. Explore About the Numerical Variables
#     3. Explore About categorical Variables
#     4. Finding Relationship between features

# %%
df_zomato.shape
# Out:
# (9551, 21)

# %%
df_zomato.size
# Out:
# 200571

# %%
df_zomato.isna()

# %%
df_zomato.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df_zomato.isnull()

# %%
df_zomato.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df_zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
for features in df_zomato.columns:
  print(features)
# Out:
# Restaurant ID
# Restaurant Name
# Country Code
# City
# Address
# Locality
# Locality Verbose
# Longitude
# Latitude
# Cuisines
# Average Cost for two
# Currency
# Has Table booking
# Has Online delivery
# Is delivering now
# Switch to order menu
# Price range
# Aggregate rating
# Rating color
# Rating text
# Votes

# %%
for features in df_zomato.columns:
  if df_zomato[features].isnull().sum()>0:
    print(features)
# Out:
# Cuisines

# %%
[features for features in df_zomato.columns if df_zomato[features].isnull().sum()>0]

# %%
sns.heatmap(df_zomato.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_country=pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_country.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
#
# how{‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, default ‘inner’
# Type of merge to be performed.
#
# left: use only keys from left frame, similar to a SQL left outer join; preserve key order.
#
# right: use only keys from right frame, similar to a SQL right outer join; preserve key order.
#
# outer: use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically.
#
# inner: use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys.
#
# cross: creates the cartesian product from both frames, preserves the order of the left keys.

# %%
final_df = pd.merge(df_zomato, df_country, on='Country Code', how='left')

# %%
final_df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
country_names=final_df.Country.value_counts().index
country_val=final_df.Country.value_counts().values
plt.pie(country_val[:3],labels=country_names[:3],autopct='%1.2f%%', explode=(0.12, 0.15, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7816b1c60190>,
# ...
#  [Text(-1.2011169177419605, 0.21381802990873458, 'India'),
#   Text(1.2241837679981318, -0.25273326288776476, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.7088558858805012, 0.12618768978220402, '94.39%'),
#   Text(0.734510260798879, -0.15163995773265884, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %%
ratings=final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 6)
sns.barplot(x="Aggregate rating",y="Rating Count",data=ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x="Aggregate rating",y="Rating Count",hue='Rating color',data=ratings,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
## Count plot
sns.countplot(x="Rating color",data=ratings,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
final_df.City.value_counts().index
city_values=final_df.City.value_counts().values
city_labels=final_df.City.value_counts().index
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7816b1c8b520>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %% [markdown]
# #**Monday Sept 11, 2023**
#
# #**Things to do**
#
#     1. EDA
#     2. Lambda
#     3. *args and **kwargs
#     4. List Comprehension

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the dataset
path = 'https://raw.githubusercontent.com/gitanuurage/EDA/main/blackFriday_train.csv'
df_train=pd.read_csv(path)
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
##  import the test data
path = 'https://raw.githubusercontent.com/gitanuurage/EDA/main/blackFriday_test.csv'
df_test=pd.read_csv(path)
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df_train.size, df_train.shape, df_train.columns
# Out:
# (6600816,
#  (550068, 12),
#  Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#         'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#         'Product_Category_2', 'Product_Category_3', 'Purchase'],
#        dtype='object'))

# %%
df_test.size, df_test.shape, df_test.columns
# Out:
# (2569589,
#  (233599, 11),
#  Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#         'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#         'Product_Category_2', 'Product_Category_3'],
#        dtype='object'))

# %%
#Merge both train and test data using the append commands, we can we merge function to
df=df_train.append(df_test)
df.head()
# Out:
# <ipython-input-40-cb7c3f0c2548>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df_train.append(df_test)
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
# ...

# %%
df.size, df.shape, df.columns
# Out:
# (9404004,
#  (783667, 12),
#  Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#         'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#         'Product_Category_2', 'Product_Category_3', 'Purchase'],
#        dtype='object'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.describe

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
 df.drop(['User_ID'], axis=1, inplace = True)
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 233594  P00118942      F  26-35          15             B
# 233595  P00254642      F  26-35          15             B
# 233596  P00031842      F  26-35          15             B
# 233597  P00124742      F  46-50           1             C
# 233598  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.Gender
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 233594    F
# 233595    F
# 233596    F
# 233597    F
# 233598    F
# Name: Gender, Length: 783667, dtype: object

# %%
df['Gender']
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 233594    F
# 233595    F
# 233596    F
# 233597    F
# 233598    F
# Name: Gender, Length: 783667, dtype: object

# %%
df['Gender']= pd.get_dummies(df['Gender'],drop_first=1)
df['Gender']
#pandas get dummies
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 233594    0
# 233595    0
# 233596    0
# 233597    0
# 233598    0
# Name: Gender, Length: 783667, dtype: uint8

# %%
# # what is categorically data
# group of variavles assign to varibales,
# gropu sof colors,
# resluts as true or false
# inmachine learning data analaysis work, we catogerized the data on the basis of aaatiributee
# gender has two or 3 genders attributes.
# dividing the category and,
# n numbers of resluts on it

# %%
# provide insight of data nd help the user to identified the problems.
# tools of EDA, helps to give reultsa and gives visulaizationon on one go.

# %%
# from seaborn._stats.counting import dataclass
# # pre processing and features processing and cleaning the data.
# # data pre processing for machine learning.
# # takes nearly 60-70 perscentage of codinf in it.
# Features selection, categorical dataclass
# mergeding the data
# we will test and train the data first then we will work o it.
# deep learning and the machine learning and data science.

# %%
# Running the EDA Commnands , deleting the columns and merging the data.

# %% [markdown]
# ****lambda FunCTION

# %%
# Lambda function, def keywords to define the function.
# There is name for the function and return paramerts.
# # there is noname for the lambda functiuon, onle lin ecode and write down in code.
# lambda function helps to solve complex problems in a short time.
#  on efunction gives the resluts for

# %%
X = lambda a: a + 10
print(X(10))
# Out:
# 20

# %%
X = lambda a,b: a*b + 10
print(X(2,8))
# Out:
# 26

# %%
x = lambda a,b,c : a*b*c +6
print(x(2,4,1))
# Out:
# 14

# %%
a = 100
b =200
if (a<150):
  print(a)
  if a < 155:
    print(a)
    if a > 160:
      print(a)
    else:
      print(b)
# Out:
# 100
# 100

# %%
result = lambda a,b : f"{x}" is smaller than {y}"\
if x<y  else (f"{x} is greater than {y}" if x>y \
              else f"{x} is equal to {y}"
print(results(12,11))
# Out:
#   File "<ipython-input-74-81533e776ae6>", line 3
#     else f"{x} is equal to {y}"
#                               ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# print stament and conditin in lambda function
